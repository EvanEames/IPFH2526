# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(9)
# Out:
# 3.0

# %%
import math as beluga_wales

# %%
from math import sqrt, pi

# %%
sqrt(9)
# Out:
# 3.0

# %%
pi
# Out:
# 3.141592653589793

# %%
from mymodule import special_greetings

# %%
special_greetings("Evan")
# Out:
# Hello Evan, you are special!

# %%
from math import *

# %%
pi
sqrt
abs
cos
sin

# %%
my_dict = {"Name": "Carl", "Age": 31, "Height": 180, "Courses": ["Intro to Python", "Hands-on ML", "Knitting"]}

# %%
my_dict
# Out:
# {'Name': 'Carl',
#  'Age': 31,
#  'Height': 180,
#  'Courses': ['Intro to Python', 'Hands-on ML', 'Knitting']}

# %%
my_dict['Courses']
# Out:
# ['Intro to Python', 'Hands-on ML', 'Knitting']

# %%
my_dict["Age"] = 32

# %%
my_dict
# Out:
# {'Name': 'Carl',
#  'Age': 32,
#  'Height': 180,
#  'Courses': ['Intro to Python', 'Hands-on ML', 'Knitting']}

# %%
del my_dict["Height"]

# %%
my_dict
# Out:
# {'Name': 'Carl',
#  'Age': 32,
#  'Courses': ['Intro to Python', 'Hands-on ML', 'Knitting']}

# %%
my_dict["Height"] = 180

# %%
my_dict
# Out:
# {'Name': 'Carl',
#  'Age': 32,
#  'Courses': ['Intro to Python', 'Hands-on ML', 'Knitting'],
#  'Height': 180}

# %%
age = my_dict.pop("Age")

# %%
my_dict
# Out:
# {'Name': 'Carl',
#  'Courses': ['Intro to Python', 'Hands-on ML', 'Knitting'],
#  'country': 'Mozambique',
#  'City': 'Denver'}

# %%
my_dict['City'] = 'Denver'

# %%
list = [7,9,11,3,6]

# %%
variable = list.pop()

# %%
variable
# Out:
# 6

# %%
list
# Out:
# [7, 9, 11, 3]

# %%
list = [["Name","Evan"], ["Age", 35], ["Country", "Canada"]]

# %%
for item in list:
    if item[0] == "Country":
        print(item[1])
# Out:
# Canada

# %%
my_dict["country"]
# Out:
# 'Mozambique'

# %%
my_dict
# Out:
# {'Name': 'Carl',
#  'Courses': ['Intro to Python', 'Hands-on ML', 'Knitting'],
#  'country': 'Mozambique',
#  'City': 'Denver'}

# %%
print(my_dict["Eye Colour"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 print(my_dict["Eye Colour"])
#
# KeyError: 'Eye Colour'

# %%
if "Eye Colour" in my_dict2:
    print(my_dict2["Eye Colour"])
else:
    my_dict2["Eye Colour"] = "Blue"
# Out:
# Red

# %%
my_dict2 = {"Eye Colour": "Red"}

# %%
for key in my_dict:
    print(key)
# Out:
# Name
# Courses
# country
# City

# %%
list(my_dict.keys())
# Out:
# ['Name', 'Courses', 'country', 'City']

# %%
list(my_dict.values())
# Out:
# ['Carl',
#  ['Intro to Python', 'Hands-on ML', 'Knitting'],
#  'Mozambique',
#  'Denver']

# %%
list(my_dict.items())
# Out:
# [('Name', 'Carl'),
#  ('Courses', ['Intro to Python', 'Hands-on ML', 'Knitting']),
#  ('country', 'Mozambique'),
#  ('City', 'Denver')]

# %%
new_dict = {}

# %%
for some word in list:
    if some word is in new_dict:
        increase that value
    else:
        add a new key/value pair (where the value is 1)
